# %%
# %pip install pandas
import pandas as pd
import sys

print(f"Version de Pandas : {pd.__version__}")
print(f"J'utilise le Python situé ici : {sys.prefix}")
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\karbe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Version de Pandas : 3.0.2
# J'utilise le Python situé ici : C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0

# %%
import pandas as pd
print("Succès !")
# Out:
# Succès !

# %%
df1 = pd.read_csv('df_clean.csv')
df1.head()
# Out:
#         id      tconst     primaryTitle    originalTitle  startYear  \
# 0  1051518  tt16194990  #ChadGetstheAxe  #ChadGetstheAxe       2022
# 1   828434  tt14433518             #FBF             #FBF       2023
# 2   605734   tt9828918         #Iamhere        #JeSuisLà       2019
# 3   455656   tt6119504     #Realityhigh     #Realityhigh       2017
# 4   295050   tt2075318           #Stuck           #Stuck       2014
#
#    runtimeMinutes                     backdrop_path  budget  \
# 0              83  /4H60noEAFazs4pRp349bbw687ld.jpg       0
# 1              83  /ylwELX3mBfzReS9uIFGAz5F2kBH.jpg       0
# 2              97  /lMbmucUTwS69tP7LdLBY7OBbPDl.jpg       0
# 3              99  /smgZYp49OB6xo4hZewxzryrh5xN.jpg       0
# 4              83  /vgrtSenEo6FhqFqwjJFVLa5lQRz.jpg       0
#
#                                  homepage original_language  ...  \
# 0                                     NaN                en  ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22540 entries, 0 to 22539
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            22540 non-null  int64
#  1   tconst                        22540 non-null  str
#  2   primaryTitle                  22540 non-null  str
#  3   originalTitle                 22540 non-null  str
#  4   startYear                     22540 non-null  int64
#  5   runtimeMinutes                22540 non-null  int64
#  6   backdrop_path                 18863 non-null  str
#  7   budget                        22540 non-null  int64
#  8   homepage                      6684 non-null   str
#  9   original_language             22540 non-null  str
#  10  overview                      22540 non-null  str
#  11  popularity                    22540 non-null  float64
#  12  poster_path                   21955 non-null  str
# ...

# %%
print(model.get_params())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(model.get_params())
#
# NameError: name 'model' is not defined
